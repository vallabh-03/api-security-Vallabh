# %% [markdown]
# <a href="https://colab.research.google.com/github/vallabh-03/api-security-Vallabh/blob/main/car_used_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Task 1

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("used_cars.csv")

# Basic exploration
print("Shape:", df.shape)
print("\nInfo:")
print(df.info())

print("\nDescribe:")
print(df.describe(include='all'))
# Out:
# Shape: (10, 5)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          10 non-null     object
#  1   model          10 non-null     object
#  2   mileage        9 non-null      object
#  3   year           10 non-null     int64
#  4   selling_price  9 non-null      float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 532.0+ bytes
# None
#
# Describe:
#          brand  model  mileage         year  selling_price
# count       10     10        9    10.000000        9.00000
# unique       8      9        8          NaN            NaN
# top     Maruti  Swift  20 kmpl          NaN            NaN
# freq         2      2        2          NaN            NaN
# mean       NaN    NaN      NaN  2017.200000   580000.00000
# std        NaN    NaN      NaN     1.813529   118743.42087
# ...

# %% [markdown]
# #Task 2

# %%
df = df.dropna(subset=['selling_price'])

# %%
# Fill numeric columns with median
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# Fill categorical columns with mode
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols] = df[cat_cols].apply(lambda x: x.fillna(x.mode()[0]))

# %%
df['brand'] = df['brand'].str.strip().str.lower()

# %%
df['mileage'] = df['mileage'].str.extract('(\d+\.?\d*)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_698/1518557609.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['mileage'] = df['mileage'].str.extract('(\d+\.?\d*)').astype(float)

# %%
df = df.drop_duplicates()

# %%
print(df.info())
print("Final Shape:", df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   brand          8 non-null      object
#  1   model          8 non-null      object
#  2   mileage        8 non-null      float64
#  3   year           8 non-null      int64
#  4   selling_price  8 non-null      float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 384.0+ bytes
# None
# Final Shape: (8, 5)

# %% [markdown]
# #Task 3

# %%
from sklearn.metrics import mean_absolute_error

# Calculate mean of target
mean_price = df['selling_price'].mean()

# Predict mean for all rows
y_true = df['selling_price']
y_pred = [mean_price] * len(df)

# Compute MAE
mae = mean_absolute_error(y_true, y_pred)

print("Baseline Mean Selling Price:", mean_price)
print("Baseline MAE:", mae)
# Out:
# Baseline Mean Selling Price: 596250.0
# Baseline MAE: 91250.0
